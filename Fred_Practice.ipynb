# %% [markdown]
# <a href="https://colab.research.google.com/github/sandhyashinde06/repo/blob/main/Fred_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **#Day 1 - 17/10**

# %%
#datatypes
'''tHIS
is a
sample file of code
 '''
a = 'Sandhya'
print(a)
a= 'Fred'
print(a)

b = 4
print(b)
b = 3
print(b)

c = 4.54545454
print(c)
c = 3.4
print(c)
# Out:
# Sandhya
# Fred
# 4
# 3
# 4.54545454
# 3.4

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

'''1. Remove "/blob"
  2. Replace github.com by raw.githubusercontent.com
  Original link for file was = https://github.com/sandhyashinde06/repo/blob/main/cancer_database.csv '''

file = pd.read_csv('https://raw.githubusercontent.com/sandhyashinde06/repo/main/cancer_database.csv')

# %%
file.head(20)
file.tail()
file.tail(10)
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1453 entries, 0 to 1452
# Data columns (total 96 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   title                          1453 non-null   object
#  1   length                         1453 non-null   int64
#  2   id                             1453 non-null   object
#  3   type                           1453 non-null   object
#  4   tissue                         855 non-null    object
#  5   subTypes                       854 non-null    float64
#  6   oncoTreeLevel                  854 non-null    float64
#  7   mainType                       854 non-null    object
#  8   parentOncoTreeId               854 non-null    object
#  9   oncoTreeId                     854 non-null    object
#  10  umls                           542 non-null    object
#  11  nciCode                        526 non-null    object
# ...

# %%
file.tail()
# Out:
#                   title  length                 id       type tissue  \
# 1448           Exercise       3           exercise  lifestyle    NaN
# 1449          Nutrition       3          nutrition  lifestyle    NaN
# 1450              Sleep       3              sleep  lifestyle    NaN
# 1451  Stress Management       3  stress-management  lifestyle    NaN
# 1452   Toxin Advoidance       3    toxin-avoidance  lifestyle    NaN
#
#       subTypes  oncoTreeLevel mainType parentOncoTreeId oncoTreeId  ...  \
# 1448       NaN            NaN      NaN              NaN        NaN  ...
# 1449       NaN            NaN      NaN              NaN        NaN  ...
# 1450       NaN            NaN      NaN              NaN        NaN  ...
# 1451       NaN            NaN      NaN              NaN        NaN  ...
# 1452       NaN            NaN      NaN              NaN        NaN  ...
#
#      github vimeo_followers vimeo telegram_followers telegram  \
# ...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1453 entries, 0 to 1452
# Data columns (total 96 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   title                          1453 non-null   object
#  1   length                         1453 non-null   int64
#  2   id                             1453 non-null   object
#  3   type                           1453 non-null   object
#  4   tissue                         855 non-null    object
#  5   subTypes                       854 non-null    float64
#  6   oncoTreeLevel                  854 non-null    float64
#  7   mainType                       854 non-null    object
#  8   parentOncoTreeId               854 non-null    object
#  9   oncoTreeId                     854 non-null    object
#  10  umls                           542 non-null    object
#  11  nciCode                        526 non-null    object
# ...

# %%
a = 'fred'
print(a)

b = 4.454
print(b)
# Out:
# fred
# 4.454

# %%
c = {'name': 'Fred45432', 'age' : 40}
print(c)
c = {'name' : 'Sandhya', 'age' : 32}
print(c)

d = {'Sandhya', 'Shinde'}
d = {'Sandhya'}
print(d)
# Out:
# {'name': 'Fred45432', 'age': 40}
# {'name': 'Sandhya', 'age': 32}
# {'Sandhya'}
